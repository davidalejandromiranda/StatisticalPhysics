# %% [markdown]
# <h1 align="center">Gases en cilindro con pistón móvil</h1>
# <div align="right"><br>David A. Miranda, PhD<br>2021</div>

# %% [markdown]
# ## 1. Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Planteamiento del problema
#
# Un contenedor cilíndrico con área transversal $A$ y longitud $L$ está separado en dos compartimentos por un pistón delgado, inicialmente fijo a una longitud $l_a$, medida desde el extremo izquierdo del cilindro. El compartimento de la izquierda contiene $\nu_a$ moles de helio gaseoso a una presión de $p_a$ atmósferas; el compartimento de la derecha está lleno con gas argón a $p_b$ atmósferas de presión. Estos gases se pueden considerar ideales.  El cilindro es sumergido en $L_{H_2O}$ litros de agua y el sistema entero está inicialmente a temperatura ambiente, 25ºC. Las capacidades caloríficas del cilindro y el pistón pueden ser despreciadas.  Cuando se retira el pistón, después de un cierto tiempo, se alcanza el estado de equilibrio cuando el pistón alcanza una nueva posición.
#
# a) ¿Cuál es la temperatura del agua cuando el sistema alcanza nuevamente el equilibrio?
#
# b) ¿Cuánto es la distancia final del pistón para diferentes posiciones iniciales?
#
# c) ¿Cuánto es la variación de la entropía de todo el sistema para diferentes posiciones iniciales?
#
# d) ¿Cómo depende la fracción molar $\nu_b$ de la posición inicial del pistón?

# %% [markdown]
# ## 3. Solución analítica
#
# ![image](https://docs.google.com/drawings/d/e/2PACX-1vR3mdAf1wuYAdfBKmVYo5JSu6bFcI5jxgcWMKqZqLXUUC5rL-4nDKmpG7n_FOiZM4dVwZj9NZ5-7XKm/pub?w=462&h=300)
#
# $\lll$ Escriba aquí su respuesta $\ggg$

# %% [markdown]
# ## 4. Resultados
# ### 4.1. Condiciones iniciales

# %%
L = 80 # cm
l_a = np.linspace(0.1*L, 0.9*L, 100) 
nu_a = 1 # mole
p_a = 5 # atm
p_b = 1 # atm

# %% [markdown]
# ### 4.2. Cálculo de variables

# %%
l_b = L - l_a
xi = p_a*l_a/(p_b*(L-l_a))
nu_b = nu_a / xi
laf = xi*L/(1+xi)
lbf = L - laf
DS = nu_a * np.log(laf/l_a) + nu_b * np.log(lbf/l_b)

# %% [markdown]
# ### 4.3. Posición final en función de la posición inicial del pistón

# %%
plt.figure(dpi=300)
plt.plot(l_a, laf)
plt.title('Figura 1')
plt.xlabel('$l_a^{(inicial)}$ [cm]')
_ = plt.ylabel('$l_a^{(final)}$ [cm]')

# %% [markdown]
# ### 4.4. Variación de la entropía total en función de la posición inicial del pistón

# %%
plt.figure(dpi=300)
plt.plot(l_a, DS)
plt.title('Figura 2')
plt.xlabel('$l_a^{(inicial)}$ [cm]')
_ = plt.ylabel(r'$\frac{\Delta S_T}{R}$  [mole]')

# %% [markdown]
# ### 4.5. Fracción molar $\nu_b$ en función de la posición inicial del pistón

# %%
plt.figure(dpi=300)
## Escriba sus comandos aquí ##

###############################
plt.title('Figura 3')
plt.xlabel('$l_a^{(inicial)}$ [cm]')
_ = plt.ylabel(r'$\nu_b$  [mole]')

# %% [markdown]
# ## 5. Preguntas de autoexplicación
#
# 5.1. Demuestre que la temperatura de todo el sistema, cuando se alcanza el equilibrio, es igual a la del estado inicial. Interprete su resultado.
#
# 5.2. Complete los pasos y figuras omitidas.
#
# 5.3. En la Figura 2 se observa un valor con máxima y otro con mínima variación de la entropía.  Interprete, en términos de las posiciones inicial y final (Figura 1), así como de las concentraciones de los gases (Figura 3), los valores máximo y mínimo para la variación de la entropía.
#
# 5.4. Exprese la entropía en $eV / K$ y $J/K$.
#
# 5.5. ¿Qué aprendió de este ejemplo?

# %% [markdown]
# End!
